# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
dataset = make_blobs(n_samples = 200, centers = 4, n_features = 2, cluster_std = 1.6, random_state = 50)

# %%
points = dataset[0]

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# kmeans = KMeans(n_clusters = 4)

# %%
kmeans.fit(points)
# Out:
# KMeans(n_clusters=4)

# %%
plt.scatter(dataset[0][:,0],dataset[0][:,1])

# %%
clusters = kmeans.cluster_centers_

# %%
print(clusters)
# Out:
# [[-5.56465793 -2.34988939]
#  [-2.40167949 10.17352695]
#  [ 0.05161133 -5.35489826]
#  [-1.92101646  5.21673484]]

# %%
y_km = kmeans.fit_predict(points)

# %%
plt.scatter(points[y_km == 0,0],points[y_km == 0,1], s=50, color = 'red')
plt.scatter(points[y_km == 1,0],points[y_km == 1,1], s=50, color = 'orange')
plt.scatter(points[y_km == 2,0],points[y_km == 2,1], s=50, color = 'blue')
plt.scatter(points[y_km == 3,0],points[y_km == 3,1], s=50, color = 'green')
plt.scatter(clusters[0][0],clusters[0][1], marker = '*', s = 200, color = 'pink')
plt.scatter(clusters[1][0],clusters[1][1], marker = '*', s = 200, color = 'red')
plt.scatter(clusters[2][0],clusters[2][1], marker = '*', s = 200, color = 'cyan')
plt.scatter(clusters[3][0],clusters[3][1], marker = '*', s = 200, color = 'black')
plt.show()
